# %% [markdown]
# <a href="https://colab.research.google.com/github/olivia-sp/smart-sv-dev/blob/main/ssv_getRoadPOI_v0_1_olivia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#도로정보DB - https://data.gg.go.kr/portal/data/dataset/searchDatasetPage.do
#GPS 데이터 기반 연산 로직 개발
#ver0.1 - 현재 위치 반경 계산 및 성남시 분당구 도로정보 필터링_신호등위치, 횡단보도위치, 도로안전표지위치

# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# #DB(csv)파일읽어오기

# %% [markdown]
# ##신호등위치(성남시분당구)

# %%
import os

if os.path.isfile('/content/drive/MyDrive/Colab Notebooks/data_set/신호등현황(개방표준).csv') == True:
  print('already')
else:
  #os.mkdir('data_set')
  # %cd data_set
  # !wget https://raw.githubusercontent.com/olivia-sp/smart-sv-dev/main/data_set/신호등현황(개방표준).csv

% cd /content
# Out:
# already
# /content

# %%
CURR_PATH = os.getcwd()

os.listdir(CURR_PATH)
#DATA_PATH = os.path.join(CURR_PATH,'data_set')
RAW_PATH = CURR_PATH + '/drive/MyDrive/Colab Notebooks/data_set/신호등현황(개방표준).csv'

# %%
raw_data_traffLgt = pd.read_csv(RAW_PATH, index_col=0, encoding='cp949')
raw_data_traffLgt.info()
raw_data_traffLgt.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2972 entries, 9 to 9
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   시군구명           2972 non-null   object
#  1   도로종류           2972 non-null   object
#  2   도로노선번호         1430 non-null   object
#  3   도로노선명          2972 non-null   object
#  4   도로노선방향         2972 non-null   int64
#  5   소재지도로명주소       564 non-null    object
#  6   소재지지번주소        1420 non-null   object
#  7   위도             1420 non-null   float64
#  8   경도             1420 non-null   float64
#  9   신호기설치방식        2972 non-null   int64
#  10  도로형태           2972 non-null   int64
#  11  주도로여부          2972 non-null   object
#  12  신호등관리번호        2972 non-null   object
#  13  신호등구분          2972 non-null   int64
#  14  신호등색종류         2972 non-null   int64
#  15  신호등화방식         2972 non-null   int64
#  16  신호등화순서         2972 non-null   object
#  17  신호등화시간         2972 non-null   object
#  18  광원종류           2972 non-null   int64
#  19  신호제어방식         2972 non-null   int64
#  20  신호시간결정방식       2972 non-null   int64
#  21  점멸등운영여부        2972 non-null   object
#  22  점멸등운영시작시각      2972 non-null   object
#  23  점멸등운영종료시각      2972 non-null   object
#  24  보행자작동신호기유무     2972 non-null   object
#  25  잔여시간표시기유무      2972 non-null   object
#  26  시각장애인용음향신호기유무  2972 non-null   object
#  27  도로안내표지일련번호     0 non-null      float64
#  28  관리기관명          2972 non-null   object
#  29  관리기관전화번호       2972 non-null   object
#  30  데이터기준일자        2972 non-null   object
# dtypes: float64(3), int64(9), object(19)
# memory usage: 743.0+ KB
# 시군구명                0
# 도로종류                0
# 도로노선번호           1542
# 도로노선명               0
# 도로노선방향              0
# 소재지도로명주소         2408
# 소재지지번주소          1552
# 위도               1552
# 경도               1552
# 신호기설치방식             0
# 도로형태                0
# 주도로여부               0
# 신호등관리번호             0
# 신호등구분               0
# 신호등색종류              0
# 신호등화방식              0
# 신호등화순서              0
# 신호등화시간              0
# 광원종류                0
# 신호제어방식              0
# 신호시간결정방식            0
# 점멸등운영여부             0
# 점멸등운영시작시각           0
# 점멸등운영종료시각           0
# 보행자작동신호기유무          0
# 잔여시간표시기유무           0
# 시각장애인용음향신호기유무       0
# 도로안내표지일련번호       2972
# 관리기관명               0
# 관리기관전화번호            0
# 데이터기준일자             0
# dtype: int64

# %%
if 'index' not in raw_data_traffLgt.columns:
  raw_data_traffLgt.reset_index(inplace=True)

# %%
raw_data_traffLgt['소재지도로명주소'] = raw_data_traffLgt['소재지도로명주소'].astype('str')
filter_city = raw_data_traffLgt['소재지도로명주소'].str.contains('분당구')
df_traffLgt_SNcity = raw_data_traffLgt[filter_city]

# %%
df_traffLgt_SNcity.reset_index(inplace=True, drop=True)

# %%
df_traffLgt_SNcity.head(2)
# Out:
#    시도명    시군구명 도로종류     도로노선번호      도로노선명  도로노선방향                 소재지도로명주소  \
# 0    9  성남시분당구   시도  판교원로 82번길  판교원로 82번길       3  경기도 성남시 분당구 판교원로82번길 60
# 1    9  성남시분당구   시도       판교역로       판교역로       3     경기도 성남시 분당구 판교역로 188
#
#                소재지지번주소         위도          경도  ...  점멸등운영여부  점멸등운영시작시각  \
# 0  경기도 성남시 분당구 운중동 916  37.384058  127.072437  ...        Y      00:00
# 1  경기도 성남시 분당구 삼평동 642  37.397392  127.109988  ...        N      00:00
#
#   점멸등운영종료시각 보행자작동신호기유무  잔여시간표시기유무  시각장애인용음향신호기유무  도로안내표지일련번호 관리기관명  \
# 0     05:30          N          N              N         NaN  성남시청
# 1     00:00          N          Y              N         NaN  성남시청
#
#        관리기관전화번호     데이터기준일자
# 0  031-729-3673  2018-08-31
# 1  031-729-3673  2018-08-31
#
# [2 rows x 32 columns]

# %% [markdown]
# ##횡단보도위치(성남시분당구)

# %%
import os

if os.path.isfile('/content/drive/MyDrive/Colab Notebooks/data_set/횡단보도현황(개방표준).csv') == True:
  print('already')
else:
  #os.mkdir('data_set')
  # %cd data_set
  # !wget https://raw.githubusercontent.com/olivia-sp/smart-sv-dev/main/data_set/횡단보도현황(개방표준).csv

% cd /content
# Out:
# already
# /content

# %%
CURR_PATH = os.getcwd()

os.listdir(CURR_PATH)
#DATA_PATH = os.path.join(CURR_PATH,'data_set')
RAW_PATH = CURR_PATH + '/drive/MyDrive/Colab Notebooks/data_set/횡단보도현황(개방표준).csv'

# %%
raw_data_crossWlk = pd.read_csv(RAW_PATH, index_col=0, encoding='cp949')
raw_data_crossWlk.info()
raw_data_crossWlk.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5003 entries, 9 to 9
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   시군구명        5003 non-null   object
#  1   도로명         5003 non-null   object
#  2   소재지도로명주소    575 non-null    object
#  3   소재지지번주소     2710 non-null   object
#  4   횡단보도관리번호    5003 non-null   object
#  5   횡단보도종류      5003 non-null   int64
#  6   자전거횡단도겸용여부  670 non-null    object
#  7   고원식적용여부     5003 non-null   object
#  8   위도          2710 non-null   float64
#  9   경도          2710 non-null   float64
#  10  차로수         5003 non-null   int64
#  11  횡단보도폭       5003 non-null   float64
#  12  횡단보도연장      5003 non-null   float64
#  13  보행자신호등유무    5003 non-null   object
#  14  보행자작동신호기유무  907 non-null    object
#  15  음향신호기설치여부   907 non-null    object
#  16  녹색신호시간      104 non-null    float64
#  17  적색신호시간      0 non-null      float64
#  18  교통섬유무       5003 non-null   object
#  19  보도턱낮춤여부     1818 non-null   object
#  20  점자블록유무      5003 non-null   object
#  21  집중조명시설유무    1048 non-null   object
#  22  관리기관명       5003 non-null   object
#  23  관리기관전화번호    5003 non-null   object
#  24  데이터기준일자     5003 non-null   object
# dtypes: float64(6), int64(2), object(17)
# memory usage: 1016.2+ KB
# 시군구명             0
# 도로명              0
# 소재지도로명주소      4428
# 소재지지번주소       2293
# 횡단보도관리번호         0
# 횡단보도종류           0
# 자전거횡단도겸용여부    4333
# 고원식적용여부          0
# 위도            2293
# 경도            2293
# 차로수              0
# 횡단보도폭            0
# 횡단보도연장           0
# 보행자신호등유무         0
# 보행자작동신호기유무    4096
# 음향신호기설치여부     4096
# 녹색신호시간        4899
# 적색신호시간        5003
# 교통섬유무            0
# 보도턱낮춤여부       3185
# 점자블록유무           0
# 집중조명시설유무      3955
# 관리기관명            0
# 관리기관전화번호         0
# 데이터기준일자          0
# dtype: int64

# %%
if 'index' not in raw_data_crossWlk.columns:
  raw_data_crossWlk.reset_index(inplace=True)

# %%
raw_data_crossWlk['소재지도로명주소'] = raw_data_crossWlk['소재지도로명주소'].astype('str')
filter_city = raw_data_crossWlk['소재지도로명주소'].str.contains('분당구')
df_crossWlk_SNcity = raw_data_crossWlk[filter_city]

# %%
df_crossWlk_SNcity.reset_index(inplace=True, drop=True)

# %%
df_crossWlk_SNcity.head(2)
# Out:
#    시도명    시군구명        도로명                                소재지도로명주소  \
# 0    9  성남시분당구  운중로 243번길                 경기도 성남시 분당구 운중로243번길 12
# 1    9  성남시분당구       동판교로  경기도 성남시 분당구 동판교로 212 (삼평동, 봇들마을6단지아파트)
#
#                             소재지지번주소 횡단보도관리번호  횡단보도종류 자전거횡단도겸용여부 고원식적용여부  \
# 0           경기도 성남시 분당구 판교동 612-4번지        -       4        NaN       N
# 1  경기도 성남시 분당구 삼평동 728번지 봇들마을6단지아파트        -       4        NaN       N
#
#           위도  ...  음향신호기설치여부  녹색신호시간  적색신호시간  교통섬유무 보도턱낮춤여부 점자블록유무 집중조명시설유무  \
# 0  37.390521  ...        NaN     NaN     NaN      N       Y      Y        Y
# 1  37.401425  ...        NaN     NaN     NaN      N       Y      Y        Y
#
#    관리기관명      관리기관전화번호     데이터기준일자
# 0   성남시청  031-729-3672  2020-06-30
# 1   성남시청  031-729-3672  2020-06-30
#
# [2 rows x 26 columns]

# %% [markdown]
# ##도로안전표지위치(성남시분당구)

# %%
import os

if os.path.isfile('/content/drive/MyDrive/Colab Notebooks/data_set/도로안전표지현황(개방표준).csv') == True:
  print('already')
else:
  #os.mkdir('data_set')
  # %cd data_set
  # !wget https://raw.githubusercontent.com/olivia-sp/smart-sv-dev/main/data_set/도로안전표지현황(개방표준).csv

% cd /content
# Out:
# already
# /content

# %%
CURR_PATH = os.getcwd()

os.listdir(CURR_PATH)
#DATA_PATH = os.path.join(CURR_PATH,'data_set')
RAW_PATH = CURR_PATH + '/drive/MyDrive/Colab Notebooks/data_set/도로안전표지현황(개방표준).csv'

# %%
raw_data_safeSgn = pd.read_csv(RAW_PATH, index_col=0, encoding='cp949')
raw_data_safeSgn.info()
raw_data_safeSgn.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1140 entries, nan to 107.0
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   도로종류        1140 non-null   object
#  1   도로노선번호      1140 non-null   object
#  2   도로노선명       1140 non-null   object
#  3   도로노선방향      1140 non-null   int64
#  4   도로형태        651 non-null    float64
#  5   차로수         0 non-null      float64
#  6   도로폭         0 non-null      float64
#  7   소재지도로명주소    599 non-null    object
#  8   소재지지번주소     1140 non-null   object
#  9   위도          1140 non-null   float64
#  10  경도          1140 non-null   float64
#  11  안전표지구분      1140 non-null   int64
#  12  안전표지종별일련번호  1140 non-null   object
#  13  주행제한속도      12 non-null     float64
#  14  안전표지설명      1140 non-null   object
#  15  지주형식        256 non-null    float64
#  16  제2외국어표기여부   0 non-null      float64
#  17  설치일자        0 non-null      float64
#  18  관리기관명       1140 non-null   object
#  19  관리기관전화번호    1140 non-null   object
#  20  데이터기준일자     1140 non-null   object
# dtypes: float64(9), int64(2), object(10)
# memory usage: 195.9+ KB
# 도로종류             0
# 도로노선번호           0
# 도로노선명            0
# 도로노선방향           0
# 도로형태           489
# 차로수           1140
# 도로폭           1140
# 소재지도로명주소       541
# 소재지지번주소          0
# 위도               0
# 경도               0
# 안전표지구분           0
# 안전표지종별일련번호       0
# 주행제한속도        1128
# 안전표지설명           0
# 지주형식           884
# 제2외국어표기여부     1140
# 설치일자          1140
# 관리기관명            0
# 관리기관전화번호         0
# 데이터기준일자          0
# dtype: int64

# %%
if 'index' not in raw_data_safeSgn.columns:
  raw_data_safeSgn.reset_index(inplace=True)

# %%
raw_data_safeSgn['소재지도로명주소'] = raw_data_safeSgn['소재지도로명주소'].astype('str')
filter_city = raw_data_safeSgn['소재지도로명주소'].str.contains('분당구')
df_safeSgn_SNcity = raw_data_safeSgn[filter_city]

# %%
df_safeSgn_SNcity.reset_index(inplace=True, drop=True)

# %% [markdown]
# #fake GPS 더미

# %%
# !pip3 install Faker
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Faker
#   Downloading Faker-13.12.0-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 16.2 MB/s
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from Faker) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->Faker) (1.15.0)
# Installing collected packages: Faker
# Successfully installed Faker-13.12.0

# %%
from faker import Faker
fake = Faker('ko_KR')
# for _ in range(5):
#   latlng = fake.local_latlng('KR')
#   print(latlng)

latlng = fake.local_latlng('KR')
print(latlng)
lat = float (latlng[0])
lon = float (latlng[1])
my_latlng = (lat, lon)
print(my_latlng)
# Out:
# ('37.1759', '128.9889', 'T‚Äôaebaek', 'KR', 'Asia/Seoul')
# (37.1759, 128.9889)

# %% [markdown]
# # 현재 위치 반경 계산

# %%
# !pip3 install haversine
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: haversine in /usr/local/lib/python3.7/dist-packages (2.5.1)

# %%
### 공식문서 예시
# from haversine import haversine, Unit

# lyon = (45.7597, 4.8422) # (lat, lon)
# paris = (48.8567, 2.3508)

# haversine(lyon, paris)
# >> 392.2172595594006  # in kilometers

# haversine(lyon, paris, unit=Unit.MILES)
# >> 243.71201856934454  # in miles

# # you can also use the string abbreviation for units:
# haversine(lyon, paris, unit='mi')
# >> 243.71201856934454  # in miles

# haversine(lyon, paris, unit=Unit.NAUTICAL_MILES)
# >> 211.78037755311516  # in nautical miles

# %%
df_traffLgt_SNcity.info()
df_crossWlk_SNcity.info()
df_safeSgn_SNcity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   시도명            298 non-null    int64
#  1   시군구명           298 non-null    object
#  2   도로종류           298 non-null    object
#  3   도로노선번호         298 non-null    object
#  4   도로노선명          298 non-null    object
#  5   도로노선방향         298 non-null    int64
#  6   소재지도로명주소       298 non-null    object
#  7   소재지지번주소        298 non-null    object
#  8   위도             298 non-null    float64
#  9   경도             298 non-null    float64
#  10  신호기설치방식        298 non-null    int64
#  11  도로형태           298 non-null    int64
#  12  주도로여부          298 non-null    object
#  13  신호등관리번호        298 non-null    object
#  14  신호등구분          298 non-null    int64
#  15  신호등색종류         298 non-null    int64
#  16  신호등화방식         298 non-null    int64
#  17  신호등화순서         298 non-null    object
#  18  신호등화시간         298 non-null    object
#  19  광원종류           298 non-null    int64
#  20  신호제어방식         298 non-null    int64
#  21  신호시간결정방식       298 non-null    int64
#  22  점멸등운영여부        298 non-null    object
#  23  점멸등운영시작시각      298 non-null    object
#  24  점멸등운영종료시각      298 non-null    object
#  25  보행자작동신호기유무     298 non-null    object
#  26  잔여시간표시기유무      298 non-null    object
#  27  시각장애인용음향신호기유무  298 non-null    object
#  28  도로안내표지일련번호     0 non-null      float64
#  29  관리기관명          298 non-null    object
#  30  관리기관전화번호       298 non-null    object
#  31  데이터기준일자        298 non-null    object
# dtypes: float64(3), int64(10), object(19)
# memory usage: 74.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   시도명         311 non-null    int64
#  1   시군구명        311 non-null    object
#  2   도로명         311 non-null    object
#  3   소재지도로명주소    311 non-null    object
#  4   소재지지번주소     311 non-null    object
#  5   횡단보도관리번호    311 non-null    object
#  6   횡단보도종류      311 non-null    int64
#  7   자전거횡단도겸용여부  0 non-null      object
#  8   고원식적용여부     311 non-null    object
#  9   위도          311 non-null    float64
#  10  경도          311 non-null    float64
#  11  차로수         311 non-null    int64
#  12  횡단보도폭       311 non-null    float64
#  13  횡단보도연장      311 non-null    float64
#  14  보행자신호등유무    311 non-null    object
#  15  보행자작동신호기유무  0 non-null      object
#  16  음향신호기설치여부   0 non-null      object
#  17  녹색신호시간      0 non-null      float64
#  18  적색신호시간      0 non-null      float64
#  19  교통섬유무       311 non-null    object
#  20  보도턱낮춤여부     311 non-null    object
#  21  점자블록유무      311 non-null    object
#  22  집중조명시설유무    311 non-null    object
#  23  관리기관명       311 non-null    object
#  24  관리기관전화번호    311 non-null    object
#  25  데이터기준일자     311 non-null    object
# dtypes: float64(6), int64(3), object(17)
# memory usage: 63.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   안전표지일련번호    0 non-null      float64
#  1   도로종류        283 non-null    object
#  2   도로노선번호      283 non-null    object
#  3   도로노선명       283 non-null    object
#  4   도로노선방향      283 non-null    int64
#  5   도로형태        283 non-null    float64
#  6   차로수         0 non-null      float64
#  7   도로폭         0 non-null      float64
#  8   소재지도로명주소    283 non-null    object
#  9   소재지지번주소     283 non-null    object
#  10  위도          283 non-null    float64
#  11  경도          283 non-null    float64
#  12  안전표지구분      283 non-null    int64
#  13  안전표지종별일련번호  283 non-null    object
#  14  주행제한속도      0 non-null      float64
#  15  안전표지설명      283 non-null    object
#  16  지주형식        93 non-null     float64
#  17  제2외국어표기여부   0 non-null      float64
#  18  설치일자        0 non-null      float64
#  19  관리기관명       283 non-null    object
#  20  관리기관전화번호    283 non-null    object
#  21  데이터기준일자     283 non-null    object
# dtypes: float64(10), int64(2), object(10)
# memory usage: 48.8+ KB

# %%
#판교만도중앙연구소
my_latlng = (37.404704734328, 127.10535530866)

# %%
from haversine import haversine, Unit
distance_compare_list_traffLgt = []
distance_compare_list_crosWlk = []
distance_compare_list_safeSgn = []

df_new_traffLgt = pd.DataFrame(columns = df_traffLgt_SNcity.columns)
df_new_crosWlk = pd.DataFrame(columns = df_crossWlk_SNcity.columns)
df_new_safeSgn = pd.DataFrame(columns = df_safeSgn_SNcity.columns)

## traffic light
for i in range(df_traffLgt_SNcity.shape[0]):
    db_traffLgt = (df_traffLgt_SNcity["위도"][i], df_traffLgt_SNcity["경도"][i])
    traffLgt_num = df_traffLgt_SNcity["신호등관리번호"][i]
    result = haversine(db_traffLgt, my_latlng, unit='m')
    #반경 500m 이내
    if result <= 500:
      distance_compare_list_traffLgt.append(result)
      print('trafficLight', db_traffLgt)
      filter_lat=df_traffLgt_SNcity['위도'] == db_traffLgt[0]
      filter_lon=df_traffLgt_SNcity['경도'] == db_traffLgt[1]
      filter_num=df_traffLgt_SNcity["신호등관리번호"] == traffLgt_num #같은 위치 신호등 구분
      df = df_traffLgt_SNcity[filter_lat & filter_lon & filter_num]
      df_new_traffLgt = pd.concat([df_new_traffLgt, df], axis = 0)
df_new_traffLgt['radius'] = distance_compare_list_traffLgt
df_new_traffLgt.reset_index(inplace=True, drop=True)

# cross walk
for i in range(df_crossWlk_SNcity.shape[0]):
    db_crosWlk = (df_crossWlk_SNcity["위도"][i], df_crossWlk_SNcity["경도"][i])
    result = haversine(db_crosWlk, my_latlng, unit='m')
    #반경 500m 이내
    if result <= 500:
      distance_compare_list_crosWlk.append(result)
      print('crossWalk', db_crosWlk)
      filter_lat=df_crossWlk_SNcity['위도'] == db_crosWlk[0]
      filter_lon=df_crossWlk_SNcity['경도'] == db_crosWlk[1]
      df = df_crossWlk_SNcity[filter_lat & filter_lon]
      df_new_crosWlk = pd.concat([df_new_crosWlk, df], axis = 0)
df_new_crosWlk['radius'] = distance_compare_list_crosWlk
df_new_crosWlk.reset_index(inplace=True, drop=True)

# safe sign
for i in range(df_safeSgn_SNcity.shape[0]):
    db_safesgn = (df_safeSgn_SNcity["위도"][i], df_safeSgn_SNcity["경도"][i])
    safesgn_num = df_safeSgn_SNcity["안전표지종별일련번호"][i]
    result = haversine(db_safesgn, my_latlng, unit='m')
    #반경 500m 이내
    if result <= 500:
      distance_compare_list_safeSgn.append(result)
      print('safeSign', db_safesgn)
      filter_lat=df_safeSgn_SNcity['위도'] == db_safesgn[0]
      filter_lon=df_safeSgn_SNcity['경도'] == db_safesgn[1]
      filter_num=df_safeSgn_SNcity["안전표지종별일련번호"] == safesgn_num #같은 위치 안전표지 구분
      df = df_safeSgn_SNcity[filter_lat & filter_lon & filter_num]
      df_new_safeSgn = pd.concat([df_new_safeSgn, df], axis = 0)
df_new_safeSgn['radius'] = distance_compare_list_safeSgn
df_new_safeSgn.reset_index(inplace=True, drop=True)
# Out:
# trafficLight (37.4037259458, 127.0998775385)
# trafficLight (37.4045092638, 127.1005562139)
# trafficLight (37.4041629952, 127.1051525762)
# trafficLight (37.4044202324, 127.1097384586)
# trafficLight (37.4033105416, 127.1010177224)
# trafficLight (37.4033105416, 127.1010177224)
# trafficLight (37.4019750211, 127.1034329076)
# trafficLight (37.4045044843, 127.1061808333)
# trafficLight (37.400611472, 127.1069321778)
# trafficLight (37.4033935026, 127.1092739361)
# trafficLight (37.4027630214, 127.1090245731)
# crossWalk (37.405076, 127.100406)
# crossWalk (37.403169, 127.102582)
# crossWalk (37.402375, 127.109682)
# crossWalk (37.403942, 127.109649)
# crossWalk (37.402307, 127.102577)
# crossWalk (37.404494, 127.101492)
# crossWalk (37.400852, 127.102599)
# crossWalk (37.403902, 127.106456)
# crossWalk (37.403183, 127.105057)
# crossWalk (37.403178, 127.109643)
# safeSign (37.4033935026, 127.1092739361)
# safeSign (37.4033105416, 127.1010177224)
# safeSign (37.4019750211, 127.1034329076)
# safeSign (37.4037259458, 127.0998775385)
# safeSign (37.4045044843, 127.1061808333)
# safeSign (37.4041629952, 127.1051525762)
# safeSign (37.4044202324, 127.1097384586)
# safeSign (37.4045092638, 127.1005562139)
# safeSign (37.4033105416, 127.1010177224)
# safeSign (37.400611472, 127.1069321778)
# safeSign (37.4027630214, 127.1090245731)

# %%
df_new_traffLgt
# Out:
#    시도명    시군구명 도로종류    도로노선번호     도로노선명 도로노선방향                   소재지도로명주소  \
# 0    9  성남시분당구   시도  판교로227번길  판교로227번길      3  경기도 성남시 분당구 판교로255번길 9-22
# 1    9  성남시분당구   시도  판교로255번길  판교로255번길      3    경기도 성남시 분당구 판교로255번길 21
# 2    9  성남시분당구   시도     대왕판교로     대왕판교로      3      경기도 성남시 분당구 대왕판교로 700
# 3    9  성남시분당구   시도  판교로319번길  판교로319번길      3     경기도 성남시 분당구 판교로319번길 6
# 4    9  성남시분당구   시도  판교로255번길  판교로255번길      3        경기도 성남시 분당구 판교로 255
# 5    9  성남시분당구   시도  판교로255번길  판교로255번길      3        경기도 성남시 분당구 판교로 255
# 6    9  성남시분당구   시도  판교로256번길  판교로256번길      3     경기도 성남시 분당구 판교로256번길 7
# 7    9  성남시분당구   시도  판교로319번길  판교로319번길      3    경기도 성남시 분당구 판교로289번길 20
# 8    9  성남시분당구   시도     대왕판교로     대왕판교로      3      경기도 성남시 분당구 대왕판교로 660
# 9    9  성남시분당구   시도      판교역로      판교역로      3        경기도 성남시 분당구 판교로 315
# 10   9  성남시분당구   시도      판교역로      판교역로      3        경기도 성남시 분당구 판교로 310
#
#                   소재지지번주소         위도          경도  ... 점멸등운영시작시각 점멸등운영종료시각  \
# 0     경기도 성남시 분당구 삼평동 618  37.403726  127.099878  ...     00:00     24:00
# 1     경기도 성남시 분당구 삼평동 619  37.404509  127.100556  ...     00:00     24:00
# 2   경기도 성남시 분당구 삼평동 694-1  37.404163  127.105153  ...     00:00     00:00
# 3     경기도 성남시 분당구 삼평동 701  37.404420  127.109738  ...     00:00     24:00
# 4     경기도 성남시 분당구 삼평동 622  37.403311  127.101018  ...     19:00     07:00
# 5     경기도 성남시 분당구 삼평동 622  37.403311  127.101018  ...     19:00     07:00
# 6     경기도 성남시 분당구 삼평동 627  37.401975  127.103433  ...     00:00     24:00
# 7     경기도 성남시 분당구 삼평동 698  37.404504  127.106181  ...     00:00     24:00
# 8     경기도 성남시 분당구 삼평동 670  37.400611  127.106932  ...     00:00     00:00
# 9   경기도 성남시 분당구 삼평동 691-1  37.403394  127.109274  ...     00:00     00:00
# 10    경기도 성남시 분당구 삼평동 686  37.402763  127.109025  ...     00:00     00:00
#
#    보행자작동신호기유무 잔여시간표시기유무 시각장애인용음향신호기유무 도로안내표지일련번호 관리기관명      관리기관전화번호  \
# 0           N         Y             N        NaN  성남시청  031-729-3673
# 1           N         Y             N        NaN  성남시청  031-729-3673
# 2           N         Y             N        NaN  성남시청  031-729-3673
# 3           N         Y             N        NaN  성남시청  031-729-3673
# 4           N         Y             N        NaN  성남시청  031-729-3673
# 5           N         Y             N        NaN  성남시청  031-729-3673
# 6           N         Y             N        NaN  성남시청  031-729-3673
# 7           N         Y             N        NaN  성남시청  031-729-3673
# 8           N         Y             N        NaN  성남시청  031-729-3673
# 9           N         Y             N        NaN  성남시청  031-729-3673
# 10          N         Y             N        NaN  성남시청  031-729-3673
#
#        데이터기준일자      radius
# 0   2018-08-31  495.941268
# 1   2018-08-31  424.458830
# 2   2018-08-31   62.844060
# 3   2018-08-31  388.452280
# 4   2018-08-31  413.315719
# 5   2018-08-31  413.315719
# 6   2018-08-31  347.801003
# 7   2018-08-31   76.242248
# 8   2018-08-31  475.986541
# 9   2018-08-31  375.588331
# 10  2018-08-31  389.439165
#
# [11 rows x 33 columns]

# %%
df_new_crosWlk
# Out:
#   시도명    시군구명       도로명                   소재지도로명주소                소재지지번주소  \
# 0   9  성남시분당구  판교로255번길    경기도 성남시 분당구 판교로255번길 21  경기도 성남시 분당구 삼평동 619번지
# 1   9  성남시분당구  판교로255번길        경기도 성남시 분당구 판교로 255  경기도 성남시 분당구 삼평동 622번지
# 2   9  성남시분당구      판교역로        경기도 성남시 분당구 판교로 310  경기도 성남시 분당구 삼평동 686번지
# 3   9  성남시분당구  판교로319번길     경기도 성남시 분당구 판교로319번길 6  경기도 성남시 분당구 삼평동 701번지
# 4   9  성남시분당구  판교로256번길     경기도 성남시 분당구 판교로256번길 7  경기도 성남시 분당구 삼평동 627번지
# 5   9  성남시분당구  판교로255번길        경기도 성남시 분당구 판교로 255  경기도 성남시 분당구 삼평동 622번지
# 6   9  성남시분당구  판교로256번길  경기도 성남시 분당구 대왕판교로645번길 36  경기도 성남시 분당구 삼평동 632번지
# 7   9  성남시분당구  판교로319번길    경기도 성남시 분당구 판교로289번길 20  경기도 성남시 분당구 삼평동 698번지
# 8   9  성남시분당구     대왕판교로        경기도 성남시 분당구 판교로 289  경기도 성남시 분당구 삼평동 694번지
# 9   9  성남시분당구      판교역로    경기도 성남시 분당구 판교로319번길 13  경기도 성남시 분당구 삼평동 691번지
#
#   횡단보도관리번호 횡단보도종류 자전거횡단도겸용여부 고원식적용여부         위도  ...  녹색신호시간 적색신호시간  교통섬유무  \
# 0        -      4        NaN       N  37.405076  ...     NaN    NaN      N
# 1        -      4        NaN       N  37.403169  ...     NaN    NaN      N
# 2        -      4        NaN       N  37.402375  ...     NaN    NaN      N
# 3        -      4        NaN       N  37.403942  ...     NaN    NaN      N
# 4        -      4        NaN       N  37.402307  ...     NaN    NaN      N
# 5        -      4        NaN       N  37.404494  ...     NaN    NaN      N
# 6        -      4        NaN       N  37.400852  ...     NaN    NaN      N
# 7        -      4        NaN       N  37.403902  ...     NaN    NaN      N
# 8        -      4        NaN       N  37.403183  ...     NaN    NaN      Y
# 9        -      4        NaN       N  37.403178  ...     NaN    NaN      N
#
#    보도턱낮춤여부 점자블록유무 집중조명시설유무 관리기관명      관리기관전화번호     데이터기준일자      radius
# 0        Y      Y        Y  성남시청  031-729-3672  2020-06-30  439.113534
# 1        Y      Y        Y  성남시청  031-729-3672  2020-06-30  298.613564
# 2        Y      Y        Y  성남시청  031-729-3672  2020-06-30  461.704675
# 3        Y      Y        Y  성남시청  031-729-3672  2020-06-30  388.628723
# 4        Y      Y        Y  성남시청  031-729-3672  2020-06-30  362.367905
# 5        Y      Y        N  성남시청  031-729-3672  2020-06-30  342.048006
# 6        Y      Y        Y  성남시청  031-729-3672  2020-06-30  492.755847
# 7        Y      Y        Y  성남시청  031-729-3672  2020-06-30  131.984354
# 8        Y      Y        Y  성남시청  031-729-3672  2020-06-30  171.248703
# 9        Y      Y        Y  성남시청  031-729-3672  2020-06-30  415.041169
#
# [10 rows x 27 columns]

# %%
df_new_safeSgn
# Out:
#     안전표지일련번호 도로종류    도로노선번호     도로노선명 도로노선방향  도로형태  차로수  도로폭  \
# 0        NaN   시도      판교역로      판교역로      3   2.0  NaN  NaN
# 1        NaN   시도  판교로255번길  판교로255번길      3   2.0  NaN  NaN
# 2        NaN   시도  판교로256번길  판교로256번길      3   2.0  NaN  NaN
# 3        NaN   시도  판교로227번길  판교로227번길      3   2.0  NaN  NaN
# 4        NaN   시도  판교로319번길  판교로319번길      3   2.0  NaN  NaN
# 5        NaN   시도     대왕판교로     대왕판교로      3   2.0  NaN  NaN
# 6        NaN   시도  판교로319번길  판교로319번길      3   2.0  NaN  NaN
# 7        NaN   시도  판교로255번길  판교로255번길      3   2.0  NaN  NaN
# 8        NaN   시도  판교로255번길  판교로255번길      3   1.0  NaN  NaN
# 9        NaN   시도     대왕판교로     대왕판교로      3   2.0  NaN  NaN
# 10       NaN   시도      판교역로      판교역로      3   2.0  NaN  NaN
#
#                      소재지도로명주소                소재지지번주소  ...  안전표지종별일련번호  주행제한속도  \
# 0         경기도 성남시 분당구 판교로 315  경기도 성남시 분당구 삼평동 691-1  ...         311     NaN
# 1         경기도 성남시 분당구 판교로 255    경기도 성남시 분당구 삼평동 622  ...         214     NaN
# 2      경기도 성남시 분당구 판교로256번길 7    경기도 성남시 분당구 삼평동 627  ...         322     NaN
# 3   경기도 성남시 분당구 판교로255번길 9-22    경기도 성남시 분당구 삼평동 618  ...         322     NaN
# 4     경기도 성남시 분당구 판교로289번길 20    경기도 성남시 분당구 삼평동 698  ...         322     NaN
# 5       경기도 성남시 분당구 대왕판교로 700  경기도 성남시 분당구 삼평동 694-1  ...         311     NaN
# 6      경기도 성남시 분당구 판교로319번길 6    경기도 성남시 분당구 삼평동 701  ...         322     NaN
# 7     경기도 성남시 분당구 판교로255번길 21    경기도 성남시 분당구 삼평동 619  ...         322     NaN
# 8         경기도 성남시 분당구 판교로 255    경기도 성남시 분당구 삼평동 622  ...         329     NaN
# 9       경기도 성남시 분당구 대왕판교로 660    경기도 성남시 분당구 삼평동 670  ...         311     NaN
# 10        경기도 성남시 분당구 판교로 310    경기도 성남시 분당구 삼평동 686  ...         311     NaN
#
#    안전표지설명 지주형식  제2외국어표기여부 설치일자  관리기관명      관리기관전화번호     데이터기준일자      radius
# 0      유턴  2.0        NaN  NaN   성남시청  031-729-3673  2018-08-28  375.588331
# 1   좌회전금지  2.0        NaN  NaN   성남시청  031-729-3673  2018-08-28  413.315719
# 2    횡단보도  2.0        NaN  NaN   성남시청  031-729-3673  2018-08-28  347.801003
# 3    횡단보도  2.0        NaN  NaN   성남시청  031-729-3673  2018-08-28  495.941268
# 4    횡단보도  2.0        NaN  NaN   성남시청  031-729-3673  2018-08-28   76.242248
# 5      유턴  2.0        NaN  NaN   성남시청  031-729-3673  2018-08-28   62.844060
# 6    횡단보도  2.0        NaN  NaN   성남시청  031-729-3673  2018-08-28  388.452280
# 7    횡단보도  2.0        NaN  NaN   성남시청  031-729-3673  2018-08-28  424.458830
# 8     비보호  2.0        NaN  NaN   성남시청  031-729-3673  2018-08-28  413.315719
# 9      유턴  2.0        NaN  NaN   성남시청  031-729-3673  2018-08-28  475.986541
# 10     유턴  2.0        NaN  NaN   성남시청  031-729-3673  2018-08-28  389.439165
#
# [11 rows x 23 columns]
